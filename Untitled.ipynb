# %%
# %matplotlib notebook

# %%
# Import Dependencies
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd

# %%
# Import the CSV
obesity_data = pd.read_csv("Data/Nutrition__Physical_Activity__and_Obesity__Behavioral_Risk_Factor_Surveillance_System.csv")
obesity_data.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2011     2011           AL      Alabama
# 1       2011     2011           AL      Alabama
# 2       2011     2011           AL      Alabama
# 3       2011     2011           AL      Alabama
# 4       2011     2011           AL      Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# ...

# %%
#Find Column names
obesity_data.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
# Create DF with only YearStart, LocationDesc, Topic, Data_Value_Unit, Income
obesity_df = obesity_data[["YearStart","LocationDesc", "Topic", "Data_Value", "Income"]]
obesity_df.describe()
# Out:
#           YearStart    Data_Value
# count  53392.000000  48346.000000
# mean    2013.281465     31.156681
# std        1.693300     10.247033
# min     2011.000000      0.900000
# 25%     2012.000000     24.100000
# 50%     2013.000000     30.700000
# 75%     2015.000000     37.000000
# max     2016.000000     77.600000

# %%
obesity_df_clean = obesity_df.dropna(how='any')
obesity_df_clean.head()
# Out:
#     YearStart LocationDesc                    Topic  Data_Value  \
# 13       2011      Alabama  Obesity / Weight Status        38.5
# 14       2011      Alabama  Obesity / Weight Status        34.8
# 15       2011      Alabama  Obesity / Weight Status        35.8
# 16       2011      Alabama  Obesity / Weight Status        32.3
# 17       2011      Alabama  Obesity / Weight Status        34.1
#
#                Income
# 13  Less than $15,000
# 14  $15,000 - $24,999
# 15  $25,000 - $34,999
# 16  $35,000 - $49,999
# 17  $50,000 - $74,999

# %%
obesity_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13349 entries, 13 to 53383
# Data columns (total 5 columns):
# YearStart       13349 non-null int64
# LocationDesc    13349 non-null object
# Topic           13349 non-null object
# Data_Value      13349 non-null float64
# Income          13349 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 625.7+ KB

# %%
obesity_df_clean_final = obesity_df_clean[obesity_df_clean["Topic"]=="Obesity / Weight Status"]

# %%
obesity_df_clean_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4480 entries, 13 to 51843
# Data columns (total 5 columns):
# YearStart       4480 non-null int64
# LocationDesc    4480 non-null object
# Topic           4480 non-null object
# Data_Value      4480 non-null float64
# Income          4480 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 210.0+ KB

# %%
obesity_df_clean_final.groupby(['LocationDesc'])["Data_Value"].mean()
# Out:
# LocationDesc
# Alabama                 34.178571
# Alaska                  32.401190
# Arizona                 31.670238
# Arkansas                34.388095
# California              30.377381
# Colorado                28.335714
# Connecticut             31.465476
# Delaware                33.229762
# District of Columbia    28.101190
# Florida                 31.534524
# Georgia                 32.658333
# Guam                    32.533333
# Hawaii                  27.939286
# Idaho                   31.922619
# Illinois                31.883333
# Indiana                 33.255952
# Iowa                    33.047619
# Kansas                  32.985714
# Kentucky                33.965476
# Louisiana               34.444048
# Maine                   32.380952
# Maryland                32.458333
# Massachusetts           30.003571
# Michigan                33.098810
# Minnesota               31.360714
# Mississippi             34.978571
# Missouri                32.886905
# ...

# %%
obesity_df_clean_final.groupby('day').filter(
    lambda x : x['total_bill'].mean() > 20
)['size'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-7158dc9967bd> in <module>
# ----> 1 obesity_df_clean_final.groupby('day').filter(
#       2     lambda x : x['total_bill'].mean() > 20
#       3 )['size'].mean()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# ...
