# %%
# %matplotlib notebook

# %%
# Import Dependencies
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd

# %%
# Import the CSV
obesity_data = pd.read_csv("Data/RISKFACTORSANDACCESSTOCARE.csv")
obesity_data.head()
# Out:
#    State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0                1                 1          Autauga         Alabama
# 1                1                 3          Baldwin         Alabama
# 2                1                 5          Barbour         Alabama
# 3                1                 7             Bibb         Alabama
# 4                1                 9           Blount         Alabama
#
#   CHSI_State_Abbr  Strata_ID_Number  No_Exercise  CI_Min_No_Exercise  \
# 0              AL                29         27.8                20.7
# 1              AL                16         27.2                23.2
# 2              AL                51      -1111.1             -1111.1
# 3              AL                42      -1111.1             -1111.1
# 4              AL                28         33.5                26.3
#
#    CI_Max_No_Exercise  Few_Fruit_Veg  ...  Diabetes  CI_Min_Diabetes  \
# ...

# %%
#Find Column names
obesity_data.corr()
# Out:
#                              State_FIPS_Code  County_FIPS_Code  \
# State_FIPS_Code                     1.000000          0.166480
# County_FIPS_Code                    0.166480          1.000000
# Strata_ID_Number                    0.000187          0.044329
# No_Exercise                        -0.017913         -0.212759
# CI_Min_No_Exercise                 -0.017767         -0.213225
# CI_Max_No_Exercise                 -0.018055         -0.212295
# Few_Fruit_Veg                      -0.035827         -0.220678
# CI_Min_Fruit_Veg                   -0.035713         -0.220899
# CI_Max_Fruit_Veg                   -0.035938         -0.220458
# Obesity                            -0.043996         -0.222835
# CI_Min_Obesity                     -0.043828         -0.223267
# CI_Max_Obesity                     -0.044161         -0.222400
# High_Blood_Pres                     0.046823         -0.179181
# CI_Min_High_Blood_Pres              0.046845         -0.179370
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
risk_corr_df = obesity_data.corr()

# %%
risk_corr_df.columns
# Out:
# Index(['State_FIPS_Code', 'County_FIPS_Code', 'Strata_ID_Number',
#        'No_Exercise', 'CI_Min_No_Exercise', 'CI_Max_No_Exercise',
#        'Few_Fruit_Veg', 'CI_Min_Fruit_Veg', 'CI_Max_Fruit_Veg', 'Obesity',
#        'CI_Min_Obesity', 'CI_Max_Obesity', 'High_Blood_Pres',
#        'CI_Min_High_Blood_Pres', 'CI_Max_High_Blood_Pres', 'Smoker',
#        'CI_Min_Smoker', 'CI_Max_Smoker', 'Diabetes', 'CI_Min_Diabetes',
#        'CI_Max_Diabetes', 'Uninsured', 'Elderly_Medicare', 'Disabled_Medicare',
#        'Prim_Care_Phys_Rate', 'Dentist_Rate', 'Community_Health_Center_Ind',
#        'HPSA_Ind'],
#       dtype='object')

# %%
# Create DF with only YearStart, LocationDesc, Topic, Data_Value_Unit, Income
sub_riskfactors_df = obesity_data[["CHSI_State_Name", 'No_Exercise','Few_Fruit_Veg','Obesity','Smoker']]
sub_riskfactors_df.head()
# Out:
#   CHSI_State_Name  No_Exercise  Few_Fruit_Veg  Obesity  Smoker
# 0         Alabama         27.8           78.6     24.5    26.6
# 1         Alabama         27.2           76.2     23.6    24.6
# 2         Alabama      -1111.1        -1111.1     25.6    17.7
# 3         Alabama      -1111.1           86.6  -1111.1 -1111.1
# 4         Alabama         33.5           74.6     24.2    23.6

# %%
riskfactor_by_state = sub_riskfactors_df.groupby("CHSI_State_Name").mean()
riskfactor_by_state.head()
# Out:
#                  No_Exercise  Few_Fruit_Veg      Obesity       Smoker
# CHSI_State_Name
# Alabama          -429.968657    -488.841791  -414.713433  -298.020896
# Alaska          -1111.100000   -1111.100000 -1111.100000 -1111.100000
# Arizona           -50.406667      -5.600000   -53.186667   -55.426667
# Arkansas         -136.282667    -173.936000  -110.684000   -94.777333
# California       -369.139655    -519.446552  -369.974138  -353.615517

# %%
state = riskfactor_by_state[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-b7df4b93f622> in <module>
# ----> 1 state = riskfactor_by_state[0]
#
# ...

# %%
state
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-202074563d3b> in <module>
# ----> 1 state
#
# NameError: name 'state' is not defined

# %%
obesity_df_clean_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4480 entries, 13 to 51843
# Data columns (total 5 columns):
# YearStart       4480 non-null int64
# LocationDesc    4480 non-null object
# Topic           4480 non-null object
# Data_Value      4480 non-null float64
# Income          4480 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 210.0+ KB

# %%
obesity_df_clean_final.groupby(['LocationDesc'])["Data_Value"].mean()
# Out:
# LocationDesc
# Alabama                 34.178571
# Alaska                  32.401190
# Arizona                 31.670238
# Arkansas                34.388095
# California              30.377381
# Colorado                28.335714
# Connecticut             31.465476
# Delaware                33.229762
# District of Columbia    28.101190
# Florida                 31.534524
# Georgia                 32.658333
# Guam                    32.533333
# Hawaii                  27.939286
# Idaho                   31.922619
# Illinois                31.883333
# Indiana                 33.255952
# Iowa                    33.047619
# Kansas                  32.985714
# Kentucky                33.965476
# Louisiana               34.444048
# Maine                   32.380952
# Maryland                32.458333
# Massachusetts           30.003571
# Michigan                33.098810
# Minnesota               31.360714
# Mississippi             34.978571
# Missouri                32.886905
# ...

# %%
df.groupby('day').filter(
    lambda x : x['total_bill'].mean() > 20
)['size'].mean()
